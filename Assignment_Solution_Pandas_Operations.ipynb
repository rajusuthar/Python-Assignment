# %% [markdown]
# <a href="https://colab.research.google.com/github/rajusuthar/Python-Assignment/blob/main/Assignment_Solution_Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# # <b> Problem 1: Import Pandas and Numpy in the notebook </b>

# %%
# Import statements
import pandas as pd
import numpy as np

# %% [markdown]
# # <b> Problem 2 : Load the automobile_data.csv kept in the shared folder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Mount your drive and read the csv file. Make sure you are using the correct file path
Automobile_df = pd.read_csv('/content/drive/MyDrive/automobile_data.csv')

# %% [markdown]
# # <b> Problem 3 : Do a basic inspection and print the first and last 15 rows of your dataframe

# %%
Automobile_df.head(15)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          0               188          bmw       gas        std
# 14          1                 ?          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# 3          four        sedan          fwd           front        99.8  ...
# 4          four        sedan          4wd           front        99.4  ...
# 5           two        sedan          fwd           front        99.8  ...
# 6          four        sedan          fwd           front       105.8  ...
# 7          four        wagon          fwd           front       105.8  ...
# 8          four        sedan          fwd           front       105.8  ...
# 9           two    hatchback          4wd           front        99.5  ...
# 10          two        sedan          rwd           front       101.2  ...
# 11         four        sedan          rwd           front       101.2  ...
# 12          two        sedan          rwd           front       101.2  ...
# 13         four        sedan          rwd           front       101.2  ...
# 14         four        sedan          rwd           front       103.5  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0           130         mpfi  3.47    2.68               9.0        111
# 1           130         mpfi  3.47    2.68               9.0        111
# 2           152         mpfi  2.68    3.47               9.0        154
# 3           109         mpfi  3.19     3.4              10.0        102
# 4           136         mpfi  3.19     3.4               8.0        115
# 5           136         mpfi  3.19     3.4               8.5        110
# 6           136         mpfi  3.19     3.4               8.5        110
# 7           136         mpfi  3.19     3.4               8.5        110
# 8           131         mpfi  3.13     3.4               8.3        140
# 9           131         mpfi  3.13     3.4               7.0        160
# 10          108         mpfi   3.5     2.8               8.8        101
# 11          108         mpfi   3.5     2.8               8.8        101
# 12          164         mpfi  3.31    3.19               9.0        121
# 13          164         mpfi  3.31    3.19               9.0        121
# 14          164         mpfi  3.31    3.19               9.0        121
#
#     peak-rpm city-mpg highway-mpg  price
# 0       5000       21          27  13495
# 1       5000       21          27  16500
# 2       5000       19          26  16500
# 3       5500       24          30  13950
# 4       5500       18          22  17450
# 5       5500       19          25  15250
# 6       5500       19          25  17710
# 7       5500       19          25  18920
# 8       5500       17          20  23875
# 9       5500       16          22      ?
# 10      5800       23          29  16430
# 11      5800       23          29  16925
# 12      4250       21          28  20970
# 13      4250       21          28  21105
# 14      4250       20          25  24565
#
# [15 rows x 26 columns]

# %% [markdown]
# # <b>Problem 4 : You need to clean the data a little bit now. Replace all column values with the values <code>?</code> and <code>n.a</code> with <code>NaN</code>

# %%
def replace_(column_):
  if (column_ =='?') or (column_ == 'n.a'):
    return np.nan
  else:
    return column_

# %%
Automobile_df.apply(lambda x : replace_(x['normalized-losses']),axis=1)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      164
# 4      164
#       ...
# 200     95
# 201     95
# 202     95
# 203     95
# 204     95
# Length: 205, dtype: object

# %%
Automobile_df=Automobile_df.replace('?',np.nan)
Automobile_df=Automobile_df.replace('n.a',np.nan)

# %%
Automobile_df.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
# 2         mpfi  2.68    3.47               9.0        154      5000       19
# 3         mpfi  3.19     3.4              10.0        102      5500       24
# 4         mpfi  3.19     3.4               8.0        115      5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# # <b>Problem 5 : Print the company name which manufactured the most expensive car. Also print the price of the most expensive car

# %%
Automobile_df['price'] = pd.to_numeric(Automobile_df['price'])
Automobile_df[['make','price']][Automobile_df['price']==Automobile_df['price'].max()]
# Out:
#              make    price
# 74  mercedes-benz  45400.0

# %% [markdown]
# # <b>Problem 6 : Calculate maximum horsepowers for each company. </b>

# %%
Automobile_df['horsepower'] = pd.to_numeric(Automobile_df['horsepower'])

# %%
Automobile_companies = list(Automobile_df['make'].unique())

# %%
company_max_power_dict = {}
for company in Automobile_companies:
  company_max_power_dict[company] = Automobile_df['horsepower'][Automobile_df['make']==company].max()

# %%
company_max_power_dict
# Out:
# {'alfa-romero': 154.0,
#  'audi': 160.0,
#  'bmw': 182.0,
#  'chevrolet': 70.0,
#  'dodge': 145.0,
#  'honda': 101.0,
#  'isuzu': 90.0,
#  'jaguar': 262.0,
#  'mazda': 135.0,
#  'mercedes-benz': 184.0,
#  'mercury': 175.0,
#  'mitsubishi': 145.0,
#  'nissan': 200.0,
#  'peugot': 142.0,
#  'plymouth': 145.0,
#  'porsche': 288.0,
#  'renault': nan,
#  'saab': 160.0,
#  'subaru': 111.0,
#  'toyota': 161.0,
#  'volkswagen': 110.0,
#  'volvo': 162.0}

# %%
pd.DataFrame(company_max_power_dict.items(),columns=['Company_name','Maximum_horse_power']).sort_values(by='Maximum_horse_power')
# Out:
#      Company_name  Maximum_horse_power
# 3       chevrolet                 70.0
# 6           isuzu                 90.0
# 5           honda                101.0
# 20     volkswagen                110.0
# 18         subaru                111.0
# 8           mazda                135.0
# 13         peugot                142.0
# 4           dodge                145.0
# 11     mitsubishi                145.0
# 14       plymouth                145.0
# 0     alfa-romero                154.0
# 1            audi                160.0
# 17           saab                160.0
# 19         toyota                161.0
# 21          volvo                162.0
# 10        mercury                175.0
# 2             bmw                182.0
# 9   mercedes-benz                184.0
# 12         nissan                200.0
# 7          jaguar                262.0
# 15        porsche                288.0
# 16        renault                  NaN

# %% [markdown]
# # <b> Problem 7 : Print the total number of cars manufactured by each company

# %%
Automobile_df.shape
# Out:
# (205, 26)

# %%
Automobile_df['make'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# # <b> Problem 8 : Create a new column for the updated price. This updated price will be calculated on top of the given price - if the engine is in front, price will be same else if the engine is in rear, price will be doubled </b>

# %%
def Price_based_on_engine(price_,engine_location):
  if engine_location =='front':
    return price_
  else:
    return 2*price_

# %%
Automobile_df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
Automobile_df['Updated_price'] = Automobile_df.apply(lambda x : Price_based_on_engine(x['price'],x['engine-location']),axis=1 )

# %%
Automobile_df[['Updated_price','price','engine-location']].head(100)
# Out:
#     Updated_price    price engine-location
# 0         13495.0  13495.0           front
# 1         16500.0  16500.0           front
# 2         16500.0  16500.0           front
# 3         13950.0  13950.0           front
# 4         17450.0  17450.0           front
# ..            ...      ...             ...
# 95         7799.0   7799.0           front
# 96         7499.0   7499.0           front
# 97         7999.0   7999.0           front
# 98         8249.0   8249.0           front
# 99         8949.0   8949.0           front
#
# [100 rows x 3 columns]

# %% [markdown]
# # <b>Problem 9 : Sort the dataframe by car and price columns

# %%
Automobile_df.sort_values(by=['price','make'],ascending=[False,True])
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 74           1               NaN  mercedes-benz       gas        std
# 16           0               NaN            bmw       gas        std
# 73           0               NaN  mercedes-benz       gas        std
# 128          3               NaN        porsche       gas        std
# 17           0               NaN            bmw       gas        std
# ..         ...               ...            ...       ...        ...
# 138          2                83         subaru       gas        std
# 9            0               NaN           audi       gas      turbo
# 44           1               NaN          isuzu       gas        std
# 45           0               NaN          isuzu       gas        std
# 129          1               NaN        porsche       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 74           two      hardtop          rwd           front       112.0  ...
# 16           two        sedan          rwd           front       103.5  ...
# 73          four        sedan          rwd           front       120.9  ...
# 128          two  convertible          rwd            rear        89.5  ...
# 17          four        sedan          rwd           front       110.0  ...
# ..           ...          ...          ...             ...         ...  ...
# 138          two    hatchback          fwd           front        93.7  ...
# 9            two    hatchback          4wd           front        99.5  ...
# 44           two        sedan          fwd           front        94.5  ...
# 45          four        sedan          fwd           front        94.5  ...
# 129          two    hatchback          rwd           front        98.4  ...
#
#      fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  \
# 74          mpfi   3.8    3.35                8.0      184.0     4500
# 16          mpfi  3.62    3.39                8.0      182.0     5400
# 73          mpfi   3.8    3.35                8.0      184.0     4500
# 128         mpfi  3.74     2.9                9.5      207.0     5900
# 17          mpfi  3.62    3.39                8.0      182.0     5400
# ..           ...   ...     ...                ...        ...      ...
# 138         2bbl  3.62    2.36                9.0       69.0     4900
# 9           mpfi  3.13     3.4                7.0      160.0     5500
# 44          2bbl  3.03    3.11                9.6       70.0     5400
# 45          2bbl  3.03    3.11                9.6       70.0     5400
# 129         mpfi  3.94    3.11               10.0      288.0     5750
#
#      city-mpg highway-mpg    price Updated_price
# 74         14          16  45400.0       45400.0
# 16         16          22  41315.0       41315.0
# 73         14          16  40960.0       40960.0
# 128        17          25  37028.0       74056.0
# 17         15          20  36880.0       36880.0
# ..        ...         ...      ...           ...
# 138        31          36   5118.0        5118.0
# 9          16          22      NaN           NaN
# 44         38          43      NaN           NaN
# 45         38          43      NaN           NaN
# 129        17          28      NaN           NaN
#
# [205 rows x 27 columns]

# %% [markdown]
# # <b> Problem 10 : Create a new column which stores the number of doors in a car as integers.

# %%
Automobile_df['num-of-doors'].unique()
# Out:
# array(['two', 'four', nan], dtype=object)

# %%
def return_no_of_door(number_):
  if number_=='two':
    return 2
  elif number_ == 'four':
    return 4
  else:
    return 0

# %%
Automobile_df['Number_of_door']=Automobile_df.apply(lambda x : return_no_of_door(x['num-of-doors']),axis=1)

# %%
Automobile_df[['num-of-doors','Number_of_door']]
# Out:
#     num-of-doors  Number_of_door
# 0            two               2
# 1            two               2
# 2            two               2
# 3           four               4
# 4           four               4
# ..           ...             ...
# 200         four               4
# 201         four               4
# 202         four               4
# 203         four               4
# 204         four               4
#
# [205 rows x 2 columns]

# %% [markdown]
# # <b>Problem 11 : Concatenate the two data frames given below firstly row wise and secondly column wise.</b>
#
# <code>GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}</code>
#
# <code>japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}</code>
